# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools

# %%
df = pd.read_csv("/Users/ryantang/Desktop/Course Scheduling STEM project 2023.xlsx - fall co enrolment data.csv")
df
# Out:
#    Combination: Unnamed: 1  Fall 2022  Fall 2021  Fall 2019  mean
# 0       BIO 105   PHYS 110          1          0          0   NaN
# 1       BIO 105   MATH 120          2          2          0   NaN
# 2       BIO 105   MATH 110          1          2          2   NaN
# 3       BIO 105   CHEM 120          2          2          2   NaN
# 4       BIO 105   CHEM 130          0          1          0   NaN
# 5       BIO 105    BIO 130          1          1          1   NaN
# 6       BIO 105   MATH 114          0          0          1   NaN
# 7       BIO 115   CHEM 120          3          5         13   NaN
# 8       BIO 115   CHEM 130          0          0          2   NaN
# 9       BIO 115   MATH 110          1          1          1   NaN
# 10      BIO 115   MATH 114          2          0          2   NaN
# 11      BIO 115   MATH 120          0          0          2   NaN
# 12      BIO 115   MATH 128          0          0          2   NaN
# 13      BIO 115   PHYS 110          0          0          1   NaN
# 14      BIO 115   PHYS 230          0          0          1   NaN
# 15      BIO 130   CHEM 120          3          2          4   NaN
# 16      BIO 130   CHEM 130          1          0          0   NaN
# 17      BIO 130   MATH 110          0          0          4   NaN
# 18      BIO 130   MATH 120          4          1          1   NaN
# 19      BIO 130   MATH 128          0          0          1   NaN
# 20     CHEM 120   MATH 110          8         15         11   NaN
# 21     CHEM 120   MATH 120          4          2          6   NaN
# 22     CHEM 120   MATH 114          4          0         11   NaN
# 23     CHEM 120   MATH 128          0          0          3   NaN
# 24     CHEM 120   PHYS 110          2          0          1   NaN
# 25     CHEM 130   MATH 110          2          1          2   NaN
# 26     CHEM 130   MATH 114          1          0          0   NaN
# 27     CHEM 130   MATH 120          0          1          2   NaN
# 28     CHEM 130   MATH 128          0          0          3   NaN
# 29     CHEM 130   PHYS 110          1          0          1   NaN
# 30     CHEM 130   PHYS 230          0          0          3   NaN
# 31     MATH 110   PHYS 110          6          4          7   NaN
# 32     MATH 120   PHYS 110          3          2          3   NaN
# 33     MATH 120   PHYS 115          1          1          1   NaN
# 34     MATH 114   PHYS 110          5          3          3   NaN
# 35     MATH 128   PHYS 110          0          0          2   NaN
# 36     MATH 128   PHYS 115          0          0          1   NaN

# %%
def averages(df: pd.DataFrame):
    ranking = {}
    for i in range(37):
        mean = (df.iloc[i,2] + df.iloc[i,3] + df.iloc[i,4]) / 3
        ranking[df.iloc[i,0] + ' ' + df.iloc [i,1]] = mean
    
    sortedranking = sorted(ranking.items(), key=lambda x:x[1], reverse=True)
    return sortedranking

sortedranking = averages(df)


# make sure they do not end with a space

# %%
a_list = ['BIO 105','CHEM 120','PHYS 110','MATH 110']

def combine_pairs(my_list: list[str]):
    a = list(itertools.combinations(my_list, 2))
    y = [' '.join(i) for i in a]
    return y

def alphabetize_pairs(pair: str):
    a = pair.find(" ") + 1
    space = pair.find(" ", a)
    if pair[0] > pair[space + 1]:
        pair = pair[space + 1:] + ' ' + pair[0:space]
        return pair
        
def alphabetize_list(my_list: list[str]):
    final = []
    for i in range(len(my_list)):
        space_1 = my_list[i].find(" ")
        space_2 = my_list[i].find(" ", space_1 + 1)
        if my_list[i][0] > my_list[i][space_2 + 1]:
            final.append(alphabetize_pairs(my_list[i]))
        else:
            final.append(my_list[i])
    return final

def check_pairs(my_list: list[str]):
    total_coenrolls = 0
    for i in range(len(sortedranking)):
        for j in range(len(my_list)):
            if sortedranking[i][0] == my_list[j]:
                total_coenrolls += sortedranking[i][1]
                print(sortedranking[i][0] + " ("  + str(sortedranking[i][1]) + ")")
    return total_coenrolls

def list_to_score(my_list: list[str]):
    return check_pairs(alphabetize_list(combine_pairs(a_list)))
list_to_score(a_list)
# Out:
# CHEM 120 MATH 110 (11.333333333333334)
# MATH 110 PHYS 110 (5.666666666666667)
# BIO 105 CHEM 120 (2.0)
# BIO 105 MATH 110 (1.6666666666666667)
# CHEM 120 PHYS 110 (1.0)
# BIO 105 PHYS 110 (0.3333333333333333)
# 22.0

# %%
totaldf = pd.read_csv("/Users/ryantang/Desktop/coding/Course Scheduling STEM project 2023.xlsx - Data.csv")
totaldf
# Out:
#     Semester Academic Year  Course ID Number Subject  Course Number Section  \
# 0       Fall     2022-2023              1018      BIO           105       1
# 1       Fall     2022-2023              1019      BIO           105     1-1
# 2       Fall     2022-2023              1020      BIO           105     1-2
# 3       Fall     2021-2022              1038      BIO           105     2-1
# 4       Fall     2021-2022              1039      BIO           105     2-2
# ..       ...           ...               ...      ...           ...     ...
# 293   Spring     2019-2020              2579     PHYS          240L       0
# 294     Fall     2022-2023              1287     PHYS           125       0
# 295     Fall     2022-2023              1332     PHYS          125L       0
# 296   Spring     2019-2020              2576     PHYS          125L       2
# 297   Spring     2021-2022              2487     PHYS          125L       1
#
#     Course Type  Enrollment as of Add Date  # majored in STEM Days Start Time  \
# 0       Lecture                         29                 10   TR    10:05am
# 1    Laboratory                         15                  5    T    01:30pm
# 2    Laboratory                         14                  5    R    01:30pm
# 3    Laboratory                         12                  4    T    08:30am
# 4    Laboratory                         11                  4    R    08:30am
# ..          ...                        ...                ...  ...        ...
# 293  Laboratory                          4                  4    R    01:30pm
# 294     Lecture                          0                  0  MWF    08:30am
# 295  Laboratory                          0                  0    T    08:30am
# 296  Laboratory                          0                  0    R    01:30pm
# 297  Laboratory                          0                  0    R    08:30am
#
#     End Time  Enrollment End of Term  Enrollment as of Census
# 0    11:30am                      32                       32
# 1    04:25pm                      16                       16
# 2    04:25pm                      16                       16
# 3    11:25am                      14                       14
# 4    11:25am                      15                       15
# ..       ...                     ...                      ...
# 293  04:25pm                       7                        8
# 294  09:25am                       6                        6
# 295  11:25am                       6                        6
# 296  04:25pm                       8                        8
# 297  11:25am                       3                        4
#
# [298 rows x 14 columns]

# %%
courseCounts = {}
courseCounts['Courses'] = []


for i in range(298):
    newDict = {}
    newDict['Name'] = totaldf.iloc[i, 3] + ' ' + totaldf.iloc[i, 4]
    newDict['Course Type'] = totaldf.iloc[i,6]
    newDict['Days'] = totaldf.iloc[i,9]
    newDict['Time'] = totaldf.iloc[i,10] + "-" + totaldf.iloc[i,11]
    courseCounts['Courses'].append(newDict)

print(newDict)


print(courseCounts)
#print(totaldf.iloc[0,6])
# Out:
# {'Name': 'PHYS 125L', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}
# {'Courses': [{'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '10:05am-11:30am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '08:30am-11:25am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '01:30pm-02:55pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '08:30am-11:25am'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '01:30pm-02:55pm'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '10:15am-11:40am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}, {'Name': 'BIO 115', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '09:35am-10:30am'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'W', 'time': '01:55pm-04:50pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}, {'Name': 'BIO 115', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '10:05am-11:30am'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'W', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 115', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '09:45am-10:40am'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'M', 'time': '03:15pm-06:10pm'}, {'Name': 'BIO 130', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '11:00am-11:55am'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 130', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '09:35am-10:30am'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '08:30am-11:25am'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '08:30am-11:25am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '08:30am-09:55am'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '01:30pm-02:55pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'R', 'time': '08:30am-11:25am'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'M', 'time': '03:00pm-05:55pm'}, {'Name': 'BIO 115', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '08:30am-11:25am'}, {'Name': 'BIO 115', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '09:35am-10:30am'}, {'Name': 'BIO 115', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '01:30pm-02:55pm'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'M', 'time': '03:00pm-05:55pm'}, {'Name': 'BIO 130', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 130', 'Course Type': 'Lecture', 'Days': 'MWF', 'time': '09:35am-10:30am'}, {'Name': 'BIO 105', 'Course Type': 'Lecture', 'Days': 'TR', 'time': '10:05am-11:30am'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'Days': 'T', 'time': '01:30pm-04:25pm'}, {'Name': 'BIO 105', 'Course Type': 'Laboratory', 'D ...

# %%
'''
for i in range(100): 
  if totaldf.iloc[i,6] == "Lecture":
      print(totaldf.iloc[i,3] + " " + totaldf.iloc[i,4])



class Class:
  name = ''
  time = ''
  type = ''
  
  def __init__(self, name, time, type):
    self.name = name
    self.type = type
    self.time = time

def main():
  a = Class("a", "a", "a")
  print(a.name)
  print(a.time)
  print(a.type)


if __name__ == '__main__':
    main()
'''
# Out:
# '\nfor i in range(100): \n  if totaldf.iloc[i,6] == "Lecture":\n      print(totaldf.iloc[i,3] + " " + totaldf.iloc[i,4])\n\n\n\nclass Class:\n  name = \'\'\n  time = \'\'\n  type = \'\'\n  \n  def __init__(self, name, time, type):\n    self.name = name\n    self.type = type\n    self.time = time\n\ndef main():\n  a = Class("a", "a", "a")\n  print(a.name)\n  print(a.time)\n  print(a.type)\n\n\nif __name__ == \'__main__\':\n    main()\n'
